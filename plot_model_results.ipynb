# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
./results/faster-rcnn/05.27.2021, 13;09;26/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml

# %%
df = pd.read_json('./results/faster-rcnn/05.27.2021, 13;09;26/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml/valid_metrics.json')
df
# Out:
#      data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0     0.347116  2136.852210                  0.5650                  0.404685
# 1     0.345334  2102.733680                  0.6925                  0.676190
# 2     0.345246  2088.526020                  0.7850                  0.934267
# 3     0.345803  2074.318360                  0.8175                  1.000000
# 4     0.323956  2023.326665                  0.8200                  1.000000
# ..         ...          ...                     ...                       ...
# 145   0.428129    61.797664                  0.9950                  0.000000
# 146   0.581195    46.658442                  0.9950                  0.000000
# 147   0.488095    31.218838                  0.9950                  0.000000
# 148   0.301220    15.636208                  0.9950                  0.000000
# 149   0.236076     0.000000                  0.9950                  0.000000
#
# ...

# %%
df.plot(x='iteration', y=['total_loss', 'loss_box_reg', 'loss_cls', 'loss_rpn_loc'], figsize=(10,5), grid=True)
# Out:
# <AxesSubplot:xlabel='iteration'>

# %%
df2 = pd.read_json('./results/faster-rcnn/05.22.2021, 13;19;25/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml/valid_metrics.json')
df2
# Out:
#     data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0    0.323503   886.136403                  0.5125                  0.619168
# 1    0.375155   899.746683                  0.5925                  0.773525
# 2    0.362660   908.887907                  0.7950                  1.000000
# 3    0.226325   864.514638                  0.8150                  1.000000
# 4    0.225502   841.335975                  0.8275                  1.000000
# ..        ...          ...                     ...                       ...
# 58   0.339304    49.671136                  0.9900                  0.000000
# 59   0.291503    35.524940                  0.9950                  0.000000
# 60   0.321156    21.265504                  0.9950                  0.000000
# 61   0.171149     7.095877                  0.9925                  0.000000
# 62   0.330813     0.000000                  0.9900                  0.000000
#
# ...

# %%
df2.plot(x='iteration', y=['total_loss', 'loss_box_reg', 'loss_cls', 'loss_rpn_loc'], figsize=(10,5), grid=True)
# Out:
# <AxesSubplot:xlabel='iteration'>
